# %% [raw]
# import os
# import cv2
# import glob
#
# #img_dir= "C:/Users/L1308/Downloads/weapons_dataset/handgun"
# img_dir="C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset/rifle/rifle/Images1"
# data_path= os.path.join(img_dir, '*g')
# files= glob.glob(data_path)
#
# data=[]
# for f1 in files:
#     img=cv2.imread(f1)
#     data.append(img)

# %% [raw]
# import cv2
# import os
#
# def load_images_from_folder(weapons_dataset):
#     images = []
#     for filename in os.listdir(weapons_dataset):
#         img = cv2.imread(os.path.join(weapons_dataset,filename))
#         if img is not None:
#             images.append(img)
#     return images

# %% [raw]
# print(images)

# %% [raw]
# #import the library opencv
# import cv2
# #globbing utility.
# import glob
# #select the path
# path = "C:/Users/L1308/Downloads/weapons_dataset/*.*"
# #path = "A:\MY_company\Sanpreet_Singh\Client Work\OpenCV-Sanjeev\images\*.*"
# for file in glob.glob(path):
#     print(file)
#     a= cv2.imread(file)
#     print(a)
# # %%%%%%%%%%%%%%%%%%%%%
# #conversion numpy array into rgb image to show
# #c = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
# #cv2.imshow('Color image', c)
# #wait for 1 second
# #k = cv2.waitKey(1000)
# #destroy the window
# #cv2.destroyAllWindows()

# %%
# how to find all files in a directory and subdirectory
import matplotlib.pyplot as plt
import os
for root, dirs, files in os.walk("C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset"):
    for file in files:
        if file.endswith('png'):
            #print(os.path.join(root, file))
            temp=os.path.join(root, file)
            print(temp)
# Out:
# C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset\handgun\handgun\Images1\001cba9f-d37f-40af-ac2b-0cc30cdecf31.png
# C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset\handgun\handgun\Images1\001e2163-6a0a-471c-9037-dd7c15977ce9.png
# C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset\handgun\handgun\Images1\003f0eb5-2f24-4388-a7b5-ec184ad732b1.png
# C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset\handgun\handgun\Images1\006a8322-e7ab-42d3-ade1-86d05a4f8ff3.png
# C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset\handgun\handgun\Images1\00777b66-1e9e-4727-adbb-52b6ca43fd42.png
# C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset\handgun\handgun\Images1\0083ade6-4405-4b26-bcd8-b6aaba8f1397.png
# C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset\handgun\handgun\Images1\008f380c-848d-4a12-8340-39bdc00bdab7.png
# ...

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %%
########
import os
import shutil

MAIN= 'C:/Users/shohidul/Desktop/new_weapons_dataset/handgun'
MAIN2= 'C:/Users/shohidul/Desktop/New_weapons_dataset/rifle'
MAIN3= 'C:/Users/shohidul/Desktop/New_weapons_dataset/other'

DIRS= 'C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset/handgun'
DIRS2= "C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset/rifle"
DIRS3= 'C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset/other'

for root, subdirs, files in os.walk(DIRS2):
    print('root', root)
    print('subdirs', subdirs)
    print('files', files)
    
    for file in files:
        path=os.path.join(root,file)
        shutil.copy(path, MAIN2)
# Out:
# root C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset/rifle
# subdirs ['rifle']
# files []
# root C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset/rifle\rifle
# subdirs ['Images1', 'Images113', 'Images2']
# files ['00a42542-e50b-4c7e-bdd8-51e8caf0ff73.png']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-26ea3a762a34> in <module>
#      18     for file in files:
#      19         path=os.path.join(root,file)
# ---> 20         shutil.copy(path, MAIN2)
#      21
#
# ~\Anaconda3\lib\shutil.py in copy(src, dst, follow_symlinks)
#     243     if os.path.isdir(dst):
#     244         dst = os.path.join(dst, os.path.basename(src))
# --> 245     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     246     copymode(src, dst, follow_symlinks=follow_symlinks)
#     247     return dst
#
# ...

# %%
# reading dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

DATADIR= "C:/Users/L1308/Downloads/New_folder_weapons_dataset"
CATEGORIES= ["handgun", "rifle", "other"]

for category in CATEGORIES:
    path=os.path.join(DATADIR, category) # path to handgun, rifle and other dir
    for img in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array, cmap="gray")
        #plt.imshow(numpy.real(rink))
        #plt.imshow(im.asnumpy())

        plt.show()
        break
    break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-b5248a845df9> in <module>
#       9 for category in CATEGORIES:
#      10     path=os.path.join(DATADIR, category) # path to handgun, rifle and other dir
# ---> 11     for img in os.listdir(path):
#      12         img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
#      13         plt.imshow(img_array, cmap="gray")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/shohidul/Downloads/weapons_dataset/weapons_dataset/handgun/handgun\\handgun'

# %%
print(img_array)
# Out:
# [[43 46 46 ... 66 56 53]
#  [43 46 46 ... 66 56 50]
#  [39 43 43 ... 66 56 50]
#  ...
#  [70 70 70 ... 34 34 34]
#  [70 70 70 ... 34 34 34]
#  [70 70 70 ... 34 39 39]]

# %%
print(img_array.shape)
# Out:
# (400, 704)

# %%
# normalizing the images as images are in different shape e.g landscape or portrait
IMG_SIZE=60

new_array= cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
plt.imshow(new_array, cmap='gray')
plt.show()

# %%
# creating training data set
training_data=[]

def create_training_data():
    #iterate over the dataset
    for category in CATEGORIES:
        path=os.path.join(DATADIR, category) # path to handgun, rifle and other dir
        class_num= CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                new_array= cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
                training_data.append([new_array, class_num])
            except Exception as e:
                pass
            
create_training_data()

# %%
print(len(training_data))
# Out:
# 26542

# %%
# shuffle the dataset to avoid everything is gun or rifle and so on
import random

random.shuffle(training_data)

# %%
# now we can check that our lablel is correct
for sample in training_data[:20]:
    print(sample[1])
# Out:
# 1
# 1
# 0
# 0
# 1
# 0
# 0
# 0
# 1
# 0
# 1
# 1
# 1
# 1
# 2
# 1
# 1
# 1
# 1
# 0

# %%
# assigning features and label variables
X= []
y= []

# %%
for features, label in training_data:
    X.append(features)
    y.append(label)
    
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
# saving our data
import pickle

pickle_out=open("X.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out=open("y.pickle", "wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %%
# read the data back
pickle_in=open("X.pickle", "rb")
X= pickle.load(pickle_in)

# %%
X[1]
# Out:
# array([[[124],
#         [128],
#         [130],
#         ...,
#         [184],
#         [187],
#         [177]],
#
#        [[130],
#         [136],
#         [138],
#         ...,
#         [199],
#         [190],
#         [183]],
#
#        [[139],
#         [141],
#         [142],
#         ...,
#         [201],
#         [199],
#         [199]],
#
#        ...,
#
#        [[ 28],
#         [ 25],
#         [ 26],
#         ...,
#         [ 23],
#         [ 21],
#         [ 21]],
#
#        [[ 21],
#         [ 21],
#         [ 21],
#         ...,
#         [ 28],
#         [ 22],
#         [ 21]],
#
#        [[ 21],
#         [ 21],
#         [ 21],
#         ...,
#         [ 21],
#         [ 21],
#         [ 21]]], dtype=uint8)

# %%
# now we will feed this dataset in convolutional neural network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D

import pickle
X = pickle.load(open("X.pickle", "rb"))
y = pickle.load(open("y.pickle", "rb"))

#normalizing data
tf.keras.utils.normalize(X, axis=-1, order=2)

model=Sequential()

#layer1
model.add(Conv2D(64), (3,3),input_shape=X.shape[1:])
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

#layer2
model.add(Conv2D(64), (3,3))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

#layer3
model.add(Flatten())
model.add(Dense(64))

# output layer
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss="binary_crossentropy", 
             optimizer="adam",
             metrics=['accuracy'])

model.fit(X, y, batch_size=32, validation_split=0.1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2d7b478611b8> in <module>
#       4
#       5 import pickle
# ----> 6 X = pickle.load(open("X.pickle", "rb"))
#       7 y = pickle.load(open("y.pickle", "rb"))
#       8
#
# FileNotFoundError: [Errno 2] No such file or directory: 'X.pickle'

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %%
import os
import shutil

dst= 'C:/Users/shohidul/Desktop/wepon/handgun'
dst2= 'C:/Users/shohidul/Desktop/wepon/rifle'
dst3= 'C:/Users/shohidul/Desktop/wepon/other'

src= 'C:/Users/shohidul/Desktop/weapon/handgun'
src2= 'C:/Users/shohidul/Desktop/weapon/rifle'
src3= 'C:/Users/shohidul/Desktop/weapon/other'

# %% [raw]
# for root, subdirs, files in os.walk(src):
#     print('root', root)
#     print('subdirs', subdirs)
#     print('files', files)
#
#     for file in files:
#         path=os.path.join(root,file)
#         shutil.copy(path, dst)

# %%
for root, subdirs, files in os.walk(src2):
    print('root', root)
    print('subdirs', subdirs)
    print('files', files)
    
    for file in files:
        path=os.path.join(root,file)
        shutil.copy(path, dst2)
# Out:
# root C:/Users/shohidul/Desktop/weapon/rifle
# subdirs ['rifle']
# files []
# root C:/Users/shohidul/Desktop/weapon/rifle\rifle
# subdirs ['Images1', 'Images113', 'Images2']
# files ['00a42542-e50b-4c7e-bdd8-51e8caf0ff73.png']
# root C:/Users/shohidul/Desktop/weapon/rifle\rifle\Images1
# subdirs []
# ...

# %%
for root, subdirs, files in os.walk(src3):
    print('root', root)
    print('subdirs', subdirs)
    print('files', files)
    
    for file in files:
        path=os.path.join(root,file)
        shutil.copy(path, dst3)
# Out:
# root C:/Users/shohidul/Desktop/weapon/other
# subdirs ['other']
# files []
# root C:/Users/shohidul/Desktop/weapon/other\other
# subdirs ['Images1', 'Images113', 'Images2']
# files []
# root C:/Users/shohidul/Desktop/weapon/other\other\Images1
# subdirs []
# ...

# %%
#image files' suffix name change!!

# %% [raw]
# import os
# os.chdir('C:/Users/shohidul/Desktop/weapon/other/other/Images113')
# i=1
# for file in os.listdir():
#       src=file
#       dst="otherg"+str(i)+".png"
#       os.rename(src,dst)
#       i+=1
